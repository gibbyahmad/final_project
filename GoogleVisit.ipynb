# %%
import pandas as pd
import json

# %%
df = pd.read_csv('googlevisittest.csv', encoding = "ISO-8859-1")

# %%
df.head()
# Out:
#   CHANNELGROUPING                   CUSTOMDIMENSIONS VISITDATE  \
# 0  Organic Search  [{'index': '4', 'value': 'EMEA'}]  18-05-11
# 1  Organic Search  [{'index': '4', 'value': 'EMEA'}]  18-05-11
# 2  Organic Search  [{'index': '4', 'value': 'APAC'}]  18-05-11
# 3  Organic Search  [{'index': '4', 'value': 'EMEA'}]  18-05-11
# 4  Organic Search  [{'index': '4', 'value': 'EMEA'}]  18-05-11
#
#                                               DEVICE        FULLVISITORID  \
# 0  {"browser": "Chrome", "browserVersion": "not a...  8460242342693915197
# 1  {"browser": "Chrome", "browserVersion": "not a...  4202952077097818366
# 2  {"browser": "Chrome", "browserVersion": "not a...  4917967184344091616
# 3  {"browser": "Chrome", "browserVersion": "not a...  5209710808778129449
# 4  {"browser": "Chrome", "browserVersion": "not a...   551350885681573094
#
#                                           GEONETWORK  \
# 0  {"continent": "Europe", "subContinent": "North...
# ...

# %%
from decimal import Decimal
import numpy
from scipy.stats import poisson
jsondf = df.to_json()
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-4-bebde717fddd> in <module>
#       2 import numpy
#       3 from scipy.stats import poisson
# ----> 4 jsondf = df.to_json()
#
# c:\users\kallurik\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\generic.py in to_json(self, path_or_buf, orient, date_format, double_precision, force_ascii, date_unit, default_handler, lines, compression, index)
#    2422             lines=lines,
#    2423             compression=compression,
# -> 2424             index=index,
#    2425         )
#    2426
#
# c:\users\kallurik\appdata\local\programs\python\python37-32\lib\site-packages\pandas\io\json\_json.py in to_json(path_or_buf, obj, orient, date_format, double_precision, force_ascii, date_unit, default_handler, lines, compression, index)
#      76         date_unit=date_unit,
# ...

# %%
jsonload = json.dumps(jsondf)
